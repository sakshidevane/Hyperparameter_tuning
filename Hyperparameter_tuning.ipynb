# %% [markdown]
# ## Manual Search

# %% [markdown]
# ### KNN

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df= sns.load_dataset("iris")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].value_counts()
#df['species'].unique()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x= df.drop('species',axis=1)
y= df['species']

# %%
x_train, x_test,y_train,y_test= train_test_split(x,y,test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import  KNeighborsClassifier

# %%
model_knn= KNeighborsClassifier(n_neighbors=3)  # 13 for max acc
# manually change the n to find max accuracy. ex- 3,5,7,9,11,13

# %%
model_knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
model_knn.score(x_test,y_test)
# Out:
# 0.98

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC

# %%
model_svm= SVC(gamma='auto')  # change the value of kernel and c value to find max accuracy

# %%
model_svm.fit(x_train, y_train)
# Out:
# SVC(gamma='auto')

# %%
model_svm.score(x_test, y_test)
# Out:
# 1.0

# %% [markdown]
# ## Grid Search Cross Validation

# %%
from sklearn.model_selection import GridSearchCV

# %%
classifier= GridSearchCV((model_svm),{
    'C': [1,10,20,30],
    'kernel':['rbf','linear'],
},cv=5, return_train_score=False)

# check the model acc for possible combination of c and kernel (4*2=8)
# no need for train_test_split
# data is divided into 5 parts for cross  validation , cv=5

# %%
classifier.fit(x,y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 10, 20, 30], 'kernel': ['rbf', 'linear']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([0.0061173 , 0.00263858, 0.0031661 , 0.00425892, 0.00511427,
#         0.00519414, 0.00464764, 0.0037097 ]),
#  'std_fit_time': array([3.42447901e-03, 6.39321098e-05, 5.59486219e-04, 2.70721390e-04,
#         4.99665970e-04, 9.72230418e-04, 4.01232773e-04, 1.06076084e-03]),
#  'mean_score_time': array([0.00308666, 0.00207806, 0.00257444, 0.00295796, 0.00406046,
#         0.00397468, 0.0037674 , 0.00259814]),
#  'std_score_time': array([1.32758044e-03, 5.95447239e-05, 7.42978903e-04, 5.33664286e-04,
#         3.65841525e-04, 6.59765460e-04, 4.49899652e-04, 5.74288084e-04]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20, 30, 30],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear',
#                     'rbf', 'linear'],
#               mask=[False, False, False, False, False, False, False, False],
# ...

# %%
result= pd.DataFrame(classifier.cv_results_)
result[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1          rbf         0.980000
# 1        1       linear         0.980000
# 2       10          rbf         0.980000
# 3       10       linear         0.973333
# 4       20          rbf         0.966667
# 5       20       linear         0.966667
# 6       30          rbf         0.960000
# 7       30       linear         0.960000

# %% [markdown]
# ## Randomized Search CV (cross validation )

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
classifier_r = RandomizedSearchCV((model_svm),{
    'C' : [1,10,20,30,40, 50, 60, 70],
    'kernel' :['rbf','linear'],
},n_iter = 5,cv = 5,return_train_score = False)

# when iteration/combinations  are maximum it is used
# n_iter = 5  randomly select 4 combinations which gives max acc
# 8*2 = 16 so random 5 are selected

# %%
classifier_r.fit(x,y)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(gamma='auto'), n_iter=5,
#                    param_distributions={'C': [1, 10, 20, 30, 40, 50, 60, 70],
#                                         'kernel': ['rbf', 'linear']})

# %%
results = pd.DataFrame(classifier_r.cv_results_)
results[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0       20       linear         0.966667
# 1       60       linear         0.966667
# 2       10       linear         0.973333
# 3       40       linear         0.960000
# 4       20          rbf         0.966667
